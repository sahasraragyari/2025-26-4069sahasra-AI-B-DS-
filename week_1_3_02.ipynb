# %% [markdown]
# <a href="https://colab.research.google.com/github/sahasraragyari/2025-26-4069sahasra-AI-B-DS-/blob/main/week_1_3_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
lst = [1, 2, 3, 4, 5, 6]
print(lst)
lst.remove(3)
print(lst)
lst.insert(2, 7)
print(lst)
print(len(lst))
# Out:
# [1, 2, 3, 4, 5, 6]
# [1, 2, 4, 5, 6]
# [1, 2, 7, 4, 5, 6]
# 6

# %%
#tuples
colors=("red","green","black","gray","purple")
print(colors[0])
print(colors[1])
print(colors[2])
print(colors)
# Out:
# red
# green
# black
# ('red', 'green', 'black', 'gray', 'purple')

# %%
#sets
set1={1,2,4,3,5}
set2={6,2,9,8,5}
print("union:",set1|set2)
print("intrersection:",set1&set2)
print("difference:",set1-set2)
# Out:
# union: {1, 2, 3, 4, 5, 6, 8, 9}
# intrersection: {2, 5}
# difference: {1, 3, 4}

# %%
#dictionaries
student={
    "Name":"sahasra",
    "rollno":69,
    "course":"CSE9(AI)-B"

}
print("dictionary items:")
for key,value in student.items():
  print(key,":",value)
# Out:
# dictionary items:
# Name : sahasra
# rollno : 69
# course : CSE9(AI)-B
